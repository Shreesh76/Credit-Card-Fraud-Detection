# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Credit Card Fraud Detection using Autoencoders

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from imblearn.metrics import classification_report_imbalanced
from imblearn import pipeline
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Load the data
df = pd.read_csv("/content/drive/MyDrive/dl-cc-fraud-master/data/creditcard.csv")

# %% [markdown]
# Exploratory Analysis
#
# Let us start to give a look at the data to extract useful information and understand the available informations

# %%
# Print the number of rows and features of the dataset
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# We have 31 columns: Time, V1, V2, ..., V28, Amount and Class. Let's check for missing value

# %%
# Check if some value is null
df.isnull().values.any()
# Out:
# False

# %%
# Plot the distribution of each class in a log scale
number_of_classes = pd.value_counts(df['Class'], sort = True)
number_of_classes.plot(kind = 'bar', rot=0)
plt.title("Class Distribution")
plt.xticks(range(len(number_of_classes)), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");
plt.yscale('log')

# %%
normal = df[df.Class == 0]
fraud = df[df.Class == 1]
print("Normal: {}, Frauds: {}".format(normal.shape[0], fraud.shape[0]))
# Out:
# Normal: 284315, Frauds: 492

# %% [markdown]
# We have a highly unbalanced dataset. Thus we need to perform some form of data augmentation! Let us look at the distribution of the Amout per transaction of the two classes.

# %%
fraud['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# Plot the percentage of transactions for each value >= tha $50
bins = np.linspace(50, 2500, 80)
plt.hist(normal['Amount'], bins, alpha=1, density=True, label='Normal')
plt.hist(fraud['Amount'], bins, alpha=0.8, density=True, label='Fraud')
plt.legend(loc='upper right')
plt.title("Amount by percentage of transactions (transactions \$50+)")
plt.xlabel("Transaction amount (USD)")
plt.ylabel("Percentage of transactions (%)");
plt.show()

# %%
# Plot the the amount of transactions w.r.t. time 
plt.scatter((normal['Time']/(3600)), normal['Amount'], alpha=1, label='Normal')
plt.scatter((fraud['Time']/(3600)), fraud['Amount'], alpha=1, label='Fraud')
plt.title("Amount of transaction durin Time")
plt.xlabel("Time measured from first transaction in the dataset")
plt.ylabel('Amount (USD)')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Notice that Time represent the amount of time elapsed from the first transaction. It seems that time of transaction does not matter and it is not as representative of the data. Hence it is better to drop this feature from the dataset. Let’s drop the Time column and use the scikit’s StandardScaler on the Amount. The scaler removes the mean and scales the values to unit variance

# %%
# We plot the shape of the 'cleaned' dataset
data = df.drop(['Time'], axis=1) 
data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))
data.shape
# Out:
# (284807, 30)

# %%
# Scatter subplots
plt.figure(figsize=(20,32))
for plot, feat in enumerate(data.columns[:-1]):
    plt.subplot(8, 4, (plot+1))
    title = str(feat)
    
    # Normalise to visualise the differences in distributions
    temp_df = pd.concat([data[feat], data['Class']], axis='columns')
    temp_df.groupby(by='Class')[feat].plot(kind='kde', alpha=1, legend='best', lw=2.5)
    plt.title(title)
    plt.tight_layout(); plt.margins(0.02)
    
plt.show()

# %% [markdown]
# From the plot above, we can select the most important and relevant features

# %%
data = data.drop(['V13', 'V15', 'V22', 'V23', 'V26', 'Amount'], axis=1) 
data.shape
# Out:
# (284807, 24)

# %% [markdown]
# Autoencoder
#
# Now we split the data into training and testing sets. We will reserve 20% of our data for testing.

# %%
# Split the dataset in training and testint sets
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED, shuffle=True)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)
y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)
X_train = X_train.values
X_test = X_test.values
X_train.shape
# Out:
# (227451, 23)

# %%
# We use a subset of training for validation
X_train, X_val = train_test_split(X_train, test_size = 0.1, random_state=RANDOM_SEED)
X_train.shape
# Out:
# (204705, 23)

# %%
input_dim = X_train.shape[1]
encoding_dim = 28
learning_rate = 0.001

# Build the autoencoder with 6 layers. During the encoding phase we map the input into a larger space,
# than with deconding we try to reconstruct the original vector
input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="relu", activity_regularizer=regularizers.l1(learning_rate))(input_layer)
encoder = Dense(int(encoding_dim * 2), activation="tanh")(encoder)
decoder = Dense(int(encoding_dim * 2), activation='relu')(encoder)
decoder = Dense(encoding_dim, activation='tanh')(decoder)
decoder = Dense(input_dim, activation='relu')(decoder)
model = Model(inputs=input_layer, outputs=decoder)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 23)]              0
# _________________________________________________________________
# dense (Dense)                (None, 28)                672
# _________________________________________________________________
# dense_1 (Dense)              (None, 56)                1624
# _________________________________________________________________
# dense_2 (Dense)              (None, 56)                3192
# _________________________________________________________________
# dense_3 (Dense)              (None, 28)                1596
# _________________________________________________________________
# dense_4 (Dense)              (None, 23)                667
# =================================================================
# Total params: 7,751
# Trainable params: 7,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
nb_epoch = 100
batch_size = 128
model.compile(optimizer='adam',  loss='mean_squared_error',  metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="model.h5", verbose=0, save_best_only=True)

# Train the autoencoder
tensorboard = TensorBoard(histogram_freq=0, write_graph=True, write_images=True)
history = model.fit(X_train, X_train, epochs=nb_epoch, batch_size=batch_size, shuffle=True,
                    validation_data=(X_val, X_val), verbose=1, callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 1600/1600 [==============================] - 21s 4ms/step - loss: 0.8307 - accuracy: 0.6979 - val_loss: 0.7276 - val_accuracy: 0.8986
# Epoch 2/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6650 - accuracy: 0.9077 - val_loss: 0.7015 - val_accuracy: 0.9321
# Epoch 3/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6317 - accuracy: 0.9339 - val_loss: 0.6896 - val_accuracy: 0.9404
# Epoch 4/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6311 - accuracy: 0.9474 - val_loss: 0.6862 - val_accuracy: 0.9378
# Epoch 5/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6278 - accuracy: 0.9500 - val_loss: 0.6806 - val_accuracy: 0.9540
# Epoch 6/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6211 - accuracy: 0.9574 - val_loss: 0.6791 - val_accuracy: 0.9594
# Epoch 7/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6310 - accuracy: 0.9591 - val_loss: 0.6766 - val_accuracy: 0.9643
# Epoch 8/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6389 - accuracy: 0.9577 - val_loss: 0.6769 - val_accuracy: 0.9623
# Epoch 9/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6367 - accuracy: 0.9565 - val_loss: 0.6749 - val_accuracy: 0.9693
# Epoch 10/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6147 - accuracy: 0.9623 - val_loss: 0.6763 - val_accuracy: 0.9462
# Epoch 11/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6293 - accuracy: 0.9619 - val_loss: 0.6735 - val_accuracy: 0.9619
# Epoch 12/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6334 - accuracy: 0.9634 - val_loss: 0.6729 - val_accuracy: 0.9701
# Epoch 13/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6306 - accuracy: 0.9602 - val_loss: 0.6742 - val_accuracy: 0.9633
# Epoch 14/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6308 - accuracy: 0.9625 - val_loss: 0.6715 - val_accuracy: 0.9737
# Epoch 15/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6297 - accuracy: 0.9708 - val_loss: 0.6714 - val_accuracy: 0.9752
# Epoch 16/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6274 - accuracy: 0.9708 - val_loss: 0.6734 - val_accuracy: 0.9681
# Epoch 17/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6343 - accuracy: 0.9668 - val_loss: 0.6704 - val_accuracy: 0.9720
# Epoch 18/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6243 - accuracy: 0.9722 - val_loss: 0.6710 - val_accuracy: 0.9588
# Epoch 19/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6155 - accuracy: 0.9691 - val_loss: 0.6697 - val_accuracy: 0.9716
# Epoch 20/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6242 - accuracy: 0.9679 - val_loss: 0.6702 - val_accuracy: 0.9714
# Epoch 21/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6300 - accuracy: 0.9644 - val_loss: 0.6690 - val_accuracy: 0.9766
# Epoch 22/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6280 - accuracy: 0.9698 - val_loss: 0.6715 - val_accuracy: 0.9602
# Epoch 23/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6220 - accuracy: 0.9677 - val_loss: 0.6695 - val_accuracy: 0.9763
# Epoch 24/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6261 - accuracy: 0.9692 - val_loss: 0.6702 - val_accuracy: 0.9704
# Epoch 25/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6260 - accuracy: 0.9648 - val_loss: 0.6691 - val_accuracy: 0.9774
# Epoch 26/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6257 - accuracy: 0.9652 - val_loss: 0.6681 - val_accuracy: 0.9818
# Epoch 27/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6376 - accuracy: 0.9655 - val_loss: 0.6690 - val_accuracy: 0.9663
# Epoch 28/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6194 - accuracy: 0.9695 - val_loss: 0.6695 - val_accuracy: 0.9621
# Epoch 29/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6223 - accuracy: 0.9686 - val_loss: 0.6679 - val_accuracy: 0.9737
# Epoch 30/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6112 - accuracy: 0.9704 - val_loss: 0.6690 - val_accuracy: 0.9670
# Epoch 31/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6281 - accuracy: 0.9708 - val_loss: 0.6679 - val_accuracy: 0.9704
# Epoch 32/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6299 - accuracy: 0.9698 - val_loss: 0.6672 - val_accuracy: 0.9798
# Epoch 33/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6157 - accuracy: 0.9717 - val_loss: 0.6690 - val_accuracy: 0.9620
# Epoch 34/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6188 - accuracy: 0.9685 - val_loss: 0.6671 - val_accuracy: 0.9767
# Epoch 35/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6281 - accuracy: 0.9740 - val_loss: 0.6661 - val_accuracy: 0.9797
# Epoch 36/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6213 - accuracy: 0.9688 - val_loss: 0.6659 - val_accuracy: 0.9825
# Epoch 37/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6218 - accuracy: 0.9703 - val_loss: 0.6663 - val_accuracy: 0.9771
# Epoch 38/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6154 - accuracy: 0.9710 - val_loss: 0.6692 - val_accuracy: 0.9554
# Epoch 39/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6298 - accuracy: 0.9694 - val_loss: 0.6667 - val_accuracy: 0.9722
# Epoch 40/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6337 - accuracy: 0.9691 - val_loss: 0.6677 - val_accuracy: 0.9711
# Epoch 41/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6096 - accuracy: 0.9733 - val_loss: 0.6674 - val_accuracy: 0.9726
# Epoch 42/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6187 - accuracy: 0.9742 - val_loss: 0.6683 - val_accuracy: 0.9592
# Epoch 43/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6238 - accuracy: 0.9659 - val_loss: 0.6658 - val_accuracy: 0.9803
# Epoch 44/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6117 - accuracy: 0.9750 - val_loss: 0.6696 - val_accuracy: 0.9447
# Epoch 45/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6278 - accuracy: 0.9697 - val_loss: 0.6659 - val_accuracy: 0.9786
# Epoch 46/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6168 - accuracy: 0.9747 - val_loss: 0.6658 - val_accuracy: 0.9778
# Epoch 47/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6146 - accuracy: 0.9753 - val_loss: 0.6660 - val_accuracy: 0.9755
# Epoch 48/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6191 - accuracy: 0.9750 - val_loss: 0.6652 - val_accuracy: 0.9818
# Epoch 49/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6272 - accuracy: 0.9720 - val_loss: 0.6670 - val_accuracy: 0.9750
# Epoch 50/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6184 - accuracy: 0.9743 - val_loss: 0.6670 - val_accuracy: 0.9687
# Epoch 51/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6376 - accuracy: 0.9668 - val_loss: 0.6683 - val_accuracy: 0.9627
# Epoch 52/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6332 - accuracy: 0.9726 - val_loss: 0.6665 - val_accuracy: 0.9661
# Epoch 53/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6207 - accuracy: 0.9722 - val_loss: 0.6659 - val_accuracy: 0.9676
# Epoch 54/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6321 - accuracy: 0.9700 - val_loss: 0.6654 - val_accuracy: 0.9713
# Epoch 55/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6259 - accuracy: 0.9696 - val_loss: 0.6667 - val_accuracy: 0.9695
# Epoch 56/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6187 - accuracy: 0.9699 - val_loss: 0.6660 - val_accuracy: 0.9680
# Epoch 57/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6301 - accuracy: 0.9750 - val_loss: 0.6653 - val_accuracy: 0.9777
# Epoch 58/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6218 - accuracy: 0.9728 - val_loss: 0.6687 - val_accuracy: 0.9689
# Epoch 59/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6331 - accuracy: 0.9720 - val_loss: 0.6657 - val_accuracy: 0.9786
# Epoch 60/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6142 - accuracy: 0.9748 - val_loss: 0.6670 - val_accuracy: 0.9769
# Epoch 61/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6305 - accuracy: 0.9725 - val_loss: 0.6651 - val_accuracy: 0.9743
# Epoch 62/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6214 - accuracy: 0.9689 - val_loss: 0.6656 - val_accuracy: 0.9788
# Epoch 63/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6227 - accuracy: 0.9732 - val_loss: 0.6650 - val_accuracy: 0.9819
# Epoch 64/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6155 - accuracy: 0.9745 - val_loss: 0.6652 - val_accuracy: 0.9680
# Epoch 65/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6354 - accuracy: 0.9703 - val_loss: 0.6648 - val_accuracy: 0.9800
# Epoch 66/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6231 - accuracy: 0.9739 - val_loss: 0.6649 - val_accuracy: 0.9766
# Epoch 67/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6283 - accuracy: 0.9738 - val_loss: 0.6646 - val_accuracy: 0.9811
# Epoch 68/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6291 - accuracy: 0.9691 - val_loss: 0.6668 - val_accuracy: 0.9698
# Epoch 69/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6327 - accuracy: 0.9690 - val_loss: 0.6659 - val_accuracy: 0.9774
# Epoch 70/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6271 - accuracy: 0.9682 - val_loss: 0.6659 - val_accuracy: 0.9810
# Epoch 71/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6257 - accuracy: 0.9732 - val_loss: 0.6656 - val_accuracy: 0.9709
# Epoch 72/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6266 - accuracy: 0.9764 - val_loss: 0.6659 - val_accuracy: 0.9534
# Epoch 73/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6173 - accuracy: 0.9719 - val_loss: 0.6652 - val_accuracy: 0.9800
# Epoch 74/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6330 - accuracy: 0.9753 - val_loss: 0.6655 - val_accuracy: 0.9665
# Epoch 75/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6145 - accuracy: 0.9747 - val_loss: 0.6651 - val_accuracy: 0.9847
# Epoch 76/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6228 - accuracy: 0.9777 - val_loss: 0.6652 - val_accuracy: 0.9786
# Epoch 77/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6437 - accuracy: 0.9746 - val_loss: 0.6648 - val_accuracy: 0.9852
# Epoch 78/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6153 - accuracy: 0.9769 - val_loss: 0.6649 - val_accuracy: 0.9804
# Epoch 79/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6192 - accuracy: 0.9757 - val_loss: 0.6655 - val_accuracy: 0.9650
# Epoch 80/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6280 - accuracy: 0.9700 - val_loss: 0.6652 - val_accuracy: 0.9788
# Epoch 81/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6361 - accuracy: 0.9750 - val_loss: 0.6648 - val_accuracy: 0.9813
# Epoch 82/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6274 - accuracy: 0.9778 - val_loss: 0.6650 - val_accuracy: 0.9717
# Epoch 83/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6257 - accuracy: 0.9731 - val_loss: 0.6674 - val_accuracy: 0.9610
# Epoch 84/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6276 - accuracy: 0.9721 - val_loss: 0.6688 - val_accuracy: 0.9443
# Epoch 85/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6198 - accuracy: 0.9739 - val_loss: 0.6699 - val_accuracy: 0.9472
# Epoch 86/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6232 - accuracy: 0.9730 - val_loss: 0.6647 - val_accuracy: 0.9817
# Epoch 87/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6296 - accuracy: 0.9764 - val_loss: 0.6644 - val_accuracy: 0.9754
# Epoch 88/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6256 - accuracy: 0.9715 - val_loss: 0.6651 - val_accuracy: 0.9757
# Epoch 89/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6203 - accuracy: 0.9771 - val_loss: 0.6651 - val_accuracy: 0.9782
# Epoch 90/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6117 - accuracy: 0.9766 - val_loss: 0.6649 - val_accuracy: 0.9840
# Epoch 91/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6187 - accuracy: 0.9770 - val_loss: 0.6684 - val_accuracy: 0.9522
# Epoch 92/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6226 - accuracy: 0.9689 - val_loss: 0.6659 - val_accuracy: 0.9836
# Epoch 93/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6362 - accuracy: 0.9704 - val_loss: 0.6654 - val_accuracy: 0.9826
# Epoch 94/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6358 - accuracy: 0.9787 - val_loss: 0.6677 - val_accuracy: 0.9778
# Epoch 95/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6282 - accuracy: 0.9747 - val_loss: 0.6656 - val_accuracy: 0.9804
# Epoch 96/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6285 - accuracy: 0.9768 - val_loss: 0.6651 - val_accuracy: 0.9847
# Epoch 97/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6231 - accuracy: 0.9741 - val_loss: 0.6697 - val_accuracy: 0.9601
# Epoch 98/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6278 - accuracy: 0.9747 - val_loss: 0.6659 - val_accuracy: 0.9723
# Epoch 99/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6272 - accuracy: 0.9761 - val_loss: 0.6648 - val_accuracy: 0.9760
# Epoch 100/100
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6286 - accuracy: 0.9765 - val_loss: 0.6662 - val_accuracy: 0.9747

# %% [markdown]
# Evaluation
#
# Let us start to evaluate the performances. First of all, we plot the loss function to check if the model has learned somethin

# %%
# Plot the loss function
plt.figure(figsize=(14,8))
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right');

# %%
# We predict new (and unseen) data to evaluate the model
predictions = model.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse, 'true_class': y_test})
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.672009      0.001720
# std                3.890323      0.041443
# min                0.009690      0.000000
# 25%                0.160890      0.000000
# 50%                0.296209      0.000000
# 75%                0.537052      0.000000
# max              350.711438      1.000000

# %%
# Plot the ROC curve
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
# Plot precision-recall curve
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
# Plot precision for different thresholds
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
# Plot recall for different thresholds
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %% [markdown]
# Our model doesn’t know how to predict new values. In order to predict whether or not a new transaction is normal or fraudulent, we’ll calculate the reconstruction error from the transaction data itself. If the error is larger than a predefined threshold, we’ll mark it as a fraud (since our model should have a low error on normal transactions)! Let’s have a look at the confusion matrix:

# %%
# We fix a threshold
threshold = 0.2

# %%
# Let us check the confusion matrix for the fixed threshold
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(14, 14))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %% [markdown]
# Alternative Model: RandomForests
#
# Let us compare the results that we obtained with an alternative and (maybe) better model. We start again splitting the dataset between train and test set.

# %%
# Again, we split into training and testing sets
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED, shuffle=True)
y_train = X_train['Class']
X_train = X_train.drop(['Class'], axis=1)
y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)
X_train.shape
# Out:
# (227845, 23)

# %%
# We use a subset of training for validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.1, random_state=RANDOM_SEED)

# %%
# We balance the dataset using an oversampling technique
smote = SMOTE(random_state=RANDOM_SEED, ratio='auto', kind='regular')
X_train_ovsamp, y_train_ovsamp = smote.fit_sample(X_train, y_train)
X_train_ovsamp.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# (409402, 23)

# %%
# Train the model
classifier = RandomForestClassifier(random_state=RANDOM_SEED)
rf_model = classifier.fit(X_train_ovsamp, y_train_ovsamp)

# %% [markdown]
# Evaluation
#
# Again, we evaluate the model. First let us check if the model has overfitted the data printing the results on validation and testing sets.

# %%
# Print the results for validation and test sets
print('Validation Results')
print(rf_model.score(X_val, y_val))
print(recall_score(y_val, rf_model.predict(X_val)))
print('\nTest Results')
print(rf_model.score(X_test, y_test))
print(recall_score(y_test, rf_model.predict(X_test)))
# Out:
# Validation Results
# 0.9997366688610928
# 0.8857142857142857
#
# Test Results
# 0.9995084442259752
# 0.8469387755102041

# %%
# Check the reconstruction error 
mse = np.mean(np.power(np.array(y_test) - rf_model.predict(X_test), 2))
error_df = pd.DataFrame({'reconstruction_error': mse, 'true_class': y_test})
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          5.696200e+04  56962.000000
# mean           4.915558e-04      0.001720
# std            4.125425e-16      0.041443
# min            4.915558e-04      0.000000
# 25%            4.915558e-04      0.000000
# 50%            4.915558e-04      0.000000
# 75%            4.915558e-04      0.000000
# max            4.915558e-04      1.000000

# %%
# Plot precision-recall curve
precision, recall, th = precision_recall_curve(y_test, rf_model.predict(X_test))
plt.figure(figsize=(14,8))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
# Plot precision for different thresholds
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
# Plot recall for different thresholds
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, rf_model.predict(X_test))
roc_auc = auc(fpr, tpr)

#Plot ROC curve
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
# Plot the confusion matrix
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(y_test, rf_model.predict(X_test))
plt.figure(figsize=(14, 14))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
